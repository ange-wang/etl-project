# %%
import pandas as pd
import requests
from splinter import Browser
from bs4 import BeautifulSoup as bs

# %%
# Initialise df with homepage table
url = 'https://www.the-numbers.com/movie/budgets/all'
response = requests.get(url)
tables = pd.read_html(response.text)
budget_df = tables[0]

# %%
budget_df
# Out:
#     Unnamed: 0   ReleaseDate                                        Movie  \
# 0            1  Apr 23, 2019                            Avengers: Endgame
# 1            2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2            3  Apr 22, 2015                      Avengers: Age of Ultron
# 3            4  Dec 16, 2015         Star Wars Ep. VII: The Force Awakens
# 4            5  Apr 25, 2018                       Avengers: Infinity War
# ..         ...           ...                                          ...
# 95          96  Jun 27, 2008                                       WALL-E
# 96          97  Aug 10, 2007                                  Rush Hour 3
# 97          98  Jun 27, 2016                         The Legend of Tarzan
# 98          99  Nov 23, 2011                                         Hugo
# 99         100  Jul 20, 2017  Valerian and the City of a Thousand Planets
#
#    ProductionBudget DomesticGross  WorldwideGross
# ...

# %%
# Iterate through all available urls to obtain full dataset
for i in range(1, 61):
    it_url = 'https://www.the-numbers.com/movie/budgets/all/' + str(i*100+1)
    response = requests.get(it_url)
    tables = pd.read_html(response.text)
    df2 = tables[0]
    print(it_url)

    budget_df = budget_df.append(df2, ignore_index=True)
# Out:
# https://www.the-numbers.com/movie/budgets/all/101
# https://www.the-numbers.com/movie/budgets/all/201
# https://www.the-numbers.com/movie/budgets/all/301
# https://www.the-numbers.com/movie/budgets/all/401
# https://www.the-numbers.com/movie/budgets/all/501
# https://www.the-numbers.com/movie/budgets/all/601
# https://www.the-numbers.com/movie/budgets/all/701
# https://www.the-numbers.com/movie/budgets/all/801
# https://www.the-numbers.com/movie/budgets/all/901
# https://www.the-numbers.com/movie/budgets/all/1001
# https://www.the-numbers.com/movie/budgets/all/1101
# https://www.the-numbers.com/movie/budgets/all/1201
# https://www.the-numbers.com/movie/budgets/all/1301
# https://www.the-numbers.com/movie/budgets/all/1401
# https://www.the-numbers.com/movie/budgets/all/1501
# https://www.the-numbers.com/movie/budgets/all/1601
# https://www.the-numbers.com/movie/budgets/all/1701
# https://www.the-numbers.com/movie/budgets/all/1801
# https://www.the-numbers.com/movie/budgets/all/1901
# ...

# %%
budget_df
# Out:
#       Unnamed: 0   ReleaseDate                                        Movie  \
# 0              1  Apr 23, 2019                            Avengers: Endgame
# 1              2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2              3  Apr 22, 2015                      Avengers: Age of Ultron
# 3              4  Dec 16, 2015         Star Wars Ep. VII: The Force Awakens
# 4              5  Apr 25, 2018                       Avengers: Infinity War
# ...          ...           ...                                          ...
# 6073        6074       Unknown                                       Red 11
# 6074        6075   Apr 2, 1999                                    Following
# 6075        6076  Jul 13, 2005                Return to the Land of Wonders
# 6076        6077  Sep 29, 2015                         A Plague So Pleasant
# 6077        6078   Aug 5, 2005                            My Date With Drew
#
#      ProductionBudget DomesticGross  WorldwideGross
# ...

# %%
clean_df = budget_df.iloc[:, 1:6]

clean_df['ProductionBudget'] = clean_df['ProductionBudget'].str.replace(',', '').\
    str.replace('$', '').astype(int)
clean_df['DomesticGross'] = clean_df['DomesticGross'].str.replace(',', '').\
    str.replace('$', '').astype(int)
clean_df['WorldwideGross'] = clean_df['WorldwideGross'].str.replace(',', '').\
    str.replace('$', '').astype(int)

# %%
clean_df
# Out:
#        ReleaseDate                                        Movie  \
# 0     Apr 23, 2019                            Avengers: Endgame
# 1     May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2     Apr 22, 2015                      Avengers: Age of Ultron
# 3     Dec 16, 2015         Star Wars Ep. VII: The Force Awakens
# 4     Apr 25, 2018                       Avengers: Infinity War
# ...            ...                                          ...
# 6073       Unknown                                       Red 11
# 6074   Apr 2, 1999                                    Following
# 6075  Jul 13, 2005                Return to the Land of Wonders
# 6076  Sep 29, 2015                         A Plague So Pleasant
# 6077   Aug 5, 2005                            My Date With Drew
#
#       ProductionBudget  DomesticGross  WorldwideGross
# 0            400000000      858373000      2797800564
# 1            379000000      241063875      1045663875
# ...

# %%
clean_df['profit_percent'] = ((clean_df['WorldwideGross']-clean_df['ProductionBudget'])/clean_df['ProductionBudget'])*100
clean_df
# Out:
#        ReleaseDate                                        Movie  \
# 0     Apr 23, 2019                            Avengers: Endgame
# 1     May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2     Apr 22, 2015                      Avengers: Age of Ultron
# 3     Dec 16, 2015         Star Wars Ep. VII: The Force Awakens
# 4     Apr 25, 2018                       Avengers: Infinity War
# ...            ...                                          ...
# 6073       Unknown                                       Red 11
# 6074   Apr 2, 1999                                    Following
# 6075  Jul 13, 2005                Return to the Land of Wonders
# 6076  Sep 29, 2015                         A Plague So Pleasant
# 6077   Aug 5, 2005                            My Date With Drew
#
#       ProductionBudget  DomesticGross  WorldwideGross  profit_percent
# 0            400000000      858373000      2797800564      599.450141
# ...

# %%
clean_df['ReleaseYear'] = ""
for index, row in clean_df.iterrows():
    if "," in str(row['ReleaseDate']):
#         row['ReleaseYear'] = str(row['ReleaseDate']).rsplit(',', 1)[1]
        clean_df.loc[index, 'ReleaseYear'] = str(row['ReleaseDate']).rsplit(',', 1)[1]
        
    elif 'Unknown' in str(row['ReleaseDate']):
        row['ReleaseDate'] = str(row['ReleaseDate']).replace('Unknown', '')
    else:
        pass

clean_df['ReleaseYear'] = clean_df['ReleaseYear'].str.replace(' ', '').\
    str.replace(' ', '')

# %%
clean_df.dtypes
# Out:
# ReleaseDate          object
# Movie                object
# ProductionBudget      int64
# DomesticGross         int64
# WorldwideGross        int64
# profit_percent      float64
# ReleaseYear          object
# dtype: object

# %%
renamed_df = clean_df.rename(columns={'ProductionBudget':'production_budget', 'DomesticGross':'domestic_gross',
                                      'WorldwideGross':'worldwide_gross'})

# %%
renamed_df.to_csv('renamed.csv')

# %%
df = pd.read_csv('Resources/imdb_movies.csv', low_memory=False)

# %%
movies_df = df[['imdb_title_id', 'original_title', 'year', 'genre', 'avg_vote']]
movies_df.head()
# Out:
#   imdb_title_id               original_title  year                      genre  \
# 0     tt0000009                   Miss Jerry  1894                    Romance
# 1     tt0000574  The Story of the Kelly Gang  1906    Biography, Crime, Drama
# 2     tt0001892               Den sorte drøm  1911                      Drama
# 3     tt0002101                    Cleopatra  1912             Drama, History
# 4     tt0002130                    L'Inferno  1911  Adventure, Drama, Fantasy
#
#    avg_vote
# 0       5.9
# 1       6.1
# 2       5.8
# 3       5.2
# 4       7.0

# %%
import jellyfish
from fuzzywuzzy import process
from fuzzywuzzy import fuzz

# %%
renamed_df.columns
# Out:
# Index(['ReleaseDate', 'Movie', 'production_budget', 'domestic_gross',
#        'worldwide_gross', 'profit_percent', 'ReleaseYear'],
#       dtype='object')

# %%
clean_df.head()
final_df = movies_df.copy()

# %%
final_df.head()
# Out:
#   imdb_title_id               original_title  year                      genre  \
# 0     tt0000009                   Miss Jerry  1894                    Romance
# 1     tt0000574  The Story of the Kelly Gang  1906    Biography, Crime, Drama
# 2     tt0001892               Den sorte drøm  1911                      Drama
# 3     tt0002101                    Cleopatra  1912             Drama, History
# 4     tt0002130                    L'Inferno  1911  Adventure, Drama, Fantasy
#
#    avg_vote
# 0       5.9
# 1       6.1
# 2       5.8
# 3       5.2
# 4       7.0

# %%
final_df['production_budget'] = ""
final_df['domestic_gross'] = ""
final_df['worldwide_gross'] = ""
final_df['profit_percent'] = ""
# final_df['ProductionBudget'] = ""

# %%
for index, row in final_df[1600:2600].iterrows():
    title = row['original_title']
    year = row['year']
    
    best_match = None
    highest_jw = 0
    for index_2, row_2 in renamed_df.iterrows():
        score = jellyfish.jaro_winkler(title.lower(), row_2['Movie'].lower())
#         print(score)
        if (score > highest_jw and score > 0.9 and str(year)==str(row_2['ReleaseYear'])):
            highest_jw = score
            production_budget = row_2['production_budget']
            domestic_gross = row_2['domestic_gross']
            worldwide_gross = row_2['worldwide_gross']
            profit_percent = row_2['profit_percent']

    if (best_match):
        final_df.loc[index,'production_budget'] = production_budget
        final_df.loc[index,'domestic_gross'] = domestic_gross
        final_df.loc[index,'worldwide_gross'] = worldwide_gross
        final_df.loc[index,'profit_percent'] = profit_percent

# %%
final_df.to_csv('movie_numbers.csv')

# %%
sorted_full = final_df.sort_values(by='profit_percent', ascending=False)
len(sorted_full)
# Out:
# 85855

# %%
final_df[:180][['domestic_gross', 'production_budget']].describe()

# %%
final_df = renamed_df.copy()

# %%
final_df.head()
# Out:
#     ReleaseDate                                        Movie  \
# 0  Apr 23, 2019                            Avengers: Endgame
# 1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2  Apr 22, 2015                      Avengers: Age of Ultron
# 3  Dec 16, 2015         Star Wars Ep. VII: The Force Awakens
# 4  Apr 25, 2018                       Avengers: Infinity War
#
#    production_budget  domestic_gross  worldwide_gross  profit_percent  \
# 0          400000000       858373000       2797800564      599.450141
# 1          379000000       241063875       1045663875      175.900759
# 2          365000000       459005868       1396099202      282.492932
# 3          306000000       936662225       2065478084      574.992838
# 4          300000000       678815482       2044540523      581.513508
#
#   ReleaseYear
# 0        2019
# 1        2011
# 2        2015
# 3        2015
# 4        2018

# %%
final_df['imdb_id'] = ""
final_df['popularity'] = ""
final_df['genre'] = ""

# %%
# final_df['ProfitPercent'] = ""
# final_df['ProductionBudget'] = ""

for index, row in final_df[1400:1500].iterrows():
    title = row['Movie']
    year = row['ReleaseYear']

    
    best_match = None
    highest_jw = 0
    for index_2, row_2 in movies_df.iterrows():
        score = jellyfish.jaro_winkler(title.lower(), row_2['original_title'].lower())
#         print(score)
        if (score > highest_jw and score > 0.9 and str(year)==str(row_2['year'])):
            highest_jw = score
            best_match = row_2['original_title']
            imdb_id = row_2['imdb_title_id']
            avg_vote = row_2['avg_vote']
            genre = row_2['genre']
            
#         if(score > highest_jw and score > 0.75):
#           highest_jw = score
#           best_match = row['Movie']
    if (best_match):
        final_df.loc[index,'imdb_id'] = imdb_id
        final_df.loc[index,'popularity'] = avg_vote
        final_df.loc[index,'genre'] = genre    
        
#     print(title)
    print(best_match, highest_jw)
# Out:
# Cleopatra 1.0
# Snatched 1.0
# Here Comes the Boom 1.0
# High Crimes 1.0
# The Mirror Has Two Faces 1.0
# Red Riding Hood 1.0
# The Mothman Prophecies 1.0
# Licence to Kill 1.0
# Holmes & Watson 1.0
# One for the Money 1.0
# 15 Minutes 1.0
# Lord of War 1.0
# Super Mario Bros. 1.0
# Hero 1.0
# Man on a Ledge 1.0
# The Warrior's Way 1.0
# McHale's Navy 1.0
# None 0
# None 0
# Pourquoi j'ai pas mangé mon père 0.9639705882352941
# 8 Mile 1.0
# Rocketman 1.0
# A Knight's Tale 0.9513725490196078
# The Medallion 1.0
# The Big Year 1.0
# The Sixth Sense 1.0
# Wedding Crashers 1.0
# The Karate Kid 1.0
# John Wick: Chapter 3 - Parabellum 0.9767965367965368
# Fifty Shades of Grey 1.0
# Knives Out 1.0
# The Proposal 1.0
# American Hustle 1.0
# Cheaper by the Dozen 1.0
# Lucy 1.0
# Lone Survivor 1.0
# Back to the Future Part II 1.0
# Double Jeopardy 1.0
# Spy Kids 3: Game Over 0.9826086956521739
# A Time to Kill 1.0
# A League of Their Own 1.0
# None 0
# The Social Network 1.0
# ...

# %%
final_df.to_csv('movie_numbers_2.csv', index=False)

# %%
final_df
# Out:
#        ReleaseDate                                        Movie  \
# 0     Apr 23, 2019                            Avengers: Endgame
# 1     May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2     Apr 22, 2015                      Avengers: Age of Ultron
# 3     Dec 16, 2015         Star Wars Ep. VII: The Force Awakens
# 4     Apr 25, 2018                       Avengers: Infinity War
# ...            ...                                          ...
# 6073       Unknown                                       Red 11
# 6074   Apr 2, 1999                                    Following
# 6075  Jul 13, 2005                Return to the Land of Wonders
# 6076  Sep 29, 2015                         A Plague So Pleasant
# 6077   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross  profit_percent  \
# 0             400000000       858373000       2797800564      599.450141
# ...

# %%
merged_df = movies_df.merge(final_df, left_on='imdb_title_id', right_on='imdb_id', how='left')
merged_df
# Out:
#       imdb_title_id                  original_title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                          genre_x  avg_vote ReleaseDate Movie  \
# 0                        Romance       5.9         NaN   NaN
# 1        Biography, Crime, Drama       6.1         NaN   NaN
# 2                          Drama       5.8         NaN   NaN
# ...

# %%
test_df = merged_df['']
# Out:
#       ReleaseDate          Movie  production_budget  domestic_gross  \
# 180  Jun 15, 2005  Batman Begins          150000000       205343774
#
#      worldwide_gross  profit_percent ReleaseYear    imdb_id popularity  \
# 180        359004502      139.336335        2005  tt0372784        8.2
#
#                  genre
# 180  Action, Adventure

# %%
output_df = test_df[['imdb_id', 'Movie', 'genre', 'popularity', 'production_budget', 
                     'domestic_gross', 'worldwide_gross', 'profit_percent']]

# %%
output_df = output_df.rename(columns= {'Movie':'original_title',})

# %%
output_df = output_df.reset_index(drop=True)
output_df
# Out:
#      imdb_id original_title              genre popularity  production_budget  \
# 0  tt0372784  Batman Begins  Action, Adventure        8.2          150000000
#
#    domestic_gross  worldwide_gross  profit_percent
# 0       205343774        359004502      139.336335

# %%
from config import username, password
from sqlalchemy import create_engine

engine = create_engine(f'postgresql://{username}:{password}@35.189.6.47:5432/moovooks123')
connection = engine.connect()

output_df.to_sql('movie_numbers', con=engine, if_exists='append', index=False)
# df2.to_sql('users', con=engine, if_exists='append')
